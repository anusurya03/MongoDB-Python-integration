# %%
import pandas as pd
import numpy as np
from pymongo import MongoClient

# %%
client = MongoClient('mongodb://localhost:27017')

# Get the sampleDB database
db = client.first

# %%
db.collection_names()
# Out:
# ['col1']

# %%
f = db.get_collection("fjson")

# %%
f.count()
# Out:
# 0

# %%
f = db.get_collection("col1")

# %%
f.count()
# Out:
# 365

# %%
f.index_information()
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)], 'ns': 'first.col1'}}

# %%
cursor = f.find({})

# %%
df = pd.DataFrame(list(cursor))

# %%
df
# Out:
#           Date        Day  Flyers  Price  Rainfall  Sales  Temperature  \
# 0   2017-01-01     Sunday      15    0.3      2.00     10         27.0
# 1   2017-01-02     Monday      15    0.3      1.33     13         28.9
# 2   2017-01-03    Tuesday      27    0.3      1.33     15         34.5
# 3   2017-01-04  Wednesday      28    0.3      1.05     17         44.1
# 4   2017-01-05   Thursday      33    0.3      1.00     18         42.4
# 5   2017-01-06     Friday      23    0.3      1.54     11         25.3
# 6   2017-01-07   Saturday      19    0.3      1.54     13         32.9
# 7   2017-01-08     Sunday      28    0.3      1.18     15         37.5
# 8   2017-01-09     Monday      20    0.3      1.18     17         38.1
# 9   2017-01-10    Tuesday      33    0.3      1.05     18         43.4
# 10  2017-01-11  Wednesday      23    0.3      1.54     12         32.6
# 11  2017-01-12   Thursday      16    0.3      1.33     14         38.2
# ...

# %%
df['Temperature']
# Out:
# 0      27.0
# 1      28.9
# 2      34.5
# 3      44.1
# 4      42.4
# 5      25.3
# 6      32.9
# 7      37.5
# 8      38.1
# 9      43.4
# 10     32.6
# 11     38.2
# 12     37.5
# 13     44.1
# 14     43.4
# 15     30.6
# 16     32.2
# 17     42.8
# 18     43.1
# 19     31.6
# 20     36.2
# 21     40.8
# 22     38.1
# 23     28.6
# 24     32.2
# 25     35.8
# 26     42.1
# 27     34.9
# 28     35.2
# 29     41.1
#        ...
# 335    44.1
# 336    33.5
# 337    34.9
# 338    22.0
# 339    44.7
# 340    42.1
# 341    40.5
# 342    31.2
# 343    31.3
# 344    45.1
# 345    33.5
# 346    32.2
# 347    31.9
# 348    42.1
# 349    35.5
# 350    32.2
# 351    30.9
# 352    41.4
# 353    36.8
# 354    40.5
# 355    30.9
# 356    42.4
# 357    35.8
# 358    35.5
# 359    28.9
# 360    42.7
# 361    37.8
# 362    39.5
# 363    30.9
# 364    15.1
# Name: Temperature, Length: 365, dtype: float64

# %%
df['Rainfall']
# Out:
# 0      2.00
# 1      1.33
# 2      1.33
# 3      1.05
# 4      1.00
# 5      1.54
# 6      1.54
# 7      1.18
# 8      1.18
# 9      1.05
# 10     1.54
# 11     1.33
# 12     1.33
# 13     1.05
# 14     1.11
# 15     1.67
# 16     1.43
# 17     1.18
# 18     1.18
# 19     1.43
# 20     1.25
# 21     1.11
# 22     1.05
# 23     1.54
# 24     1.25
# 25     1.25
# 26     1.05
# 27     1.33
# 28     1.33
# 29     1.05
#        ...
# 335    1.11
# 336    1.18
# 337    1.54
# 338    1.82
# 339    0.95
# 340    1.05
# 341    1.25
# 342    1.43
# 343    1.82
# 344    1.11
# 345    1.33
# 346    1.43
# 347    1.54
# 348    1.05
# 349    1.25
# 350    1.33
# 351    1.43
# 352    1.00
# 353    1.25
# 354    1.33
# 355    1.54
# 356    1.11
# 357    1.25
# 358    1.25
# 359    1.43
# 360    1.00
# 361    1.25
# 362    1.25
# 363    1.43
# 364    2.50
# Name: Rainfall, Length: 365, dtype: float64

# %%
query = {}
query["Temperature"] = {
    u"$lt": u"25"
}

# %%
dq = pd.DataFrame(list(query))

# %%
dq
# Out:
#              0
# 0  Temperature

# %%
df[0:3]
# Out:
#         Date      Day  Flyers  Price  Rainfall  Sales  Temperature  \
# 0 2017-01-01   Sunday      15    0.3      2.00     10         27.0
# 1 2017-01-02   Monday      15    0.3      1.33     13         28.9
# 2 2017-01-03  Tuesday      27    0.3      1.33     15         34.5
#
#                         _id
# 0  5b5b0008d827472478e6a2be
# 1  5b5b0008d827472478e6a2bf
# 2  5b5b0008d827472478e6a2c0

# %%
df[:5]
# Out:
#         Date        Day  Flyers  Price  Rainfall  Sales  Temperature  \
# 0 2017-01-01     Sunday      15    0.3      2.00     10         27.0
# 1 2017-01-02     Monday      15    0.3      1.33     13         28.9
# 2 2017-01-03    Tuesday      27    0.3      1.33     15         34.5
# 3 2017-01-04  Wednesday      28    0.3      1.05     17         44.1
# 4 2017-01-05   Thursday      33    0.3      1.00     18         42.4
#
#                         _id
# 0  5b5b0008d827472478e6a2be
# 1  5b5b0008d827472478e6a2bf
# 2  5b5b0008d827472478e6a2c0
# 3  5b5b0008d827472478e6a2c1
# 4  5b5b0008d827472478e6a2c2

# %%
df[1:]
# Out:
#           Date        Day  Flyers  Price  Rainfall  Sales  Temperature  \
# 1   2017-01-02     Monday      15    0.3      1.33     13         28.9
# 2   2017-01-03    Tuesday      27    0.3      1.33     15         34.5
# 3   2017-01-04  Wednesday      28    0.3      1.05     17         44.1
# 4   2017-01-05   Thursday      33    0.3      1.00     18         42.4
# 5   2017-01-06     Friday      23    0.3      1.54     11         25.3
# 6   2017-01-07   Saturday      19    0.3      1.54     13         32.9
# 7   2017-01-08     Sunday      28    0.3      1.18     15         37.5
# 8   2017-01-09     Monday      20    0.3      1.18     17         38.1
# 9   2017-01-10    Tuesday      33    0.3      1.05     18         43.4
# 10  2017-01-11  Wednesday      23    0.3      1.54     12         32.6
# 11  2017-01-12   Thursday      16    0.3      1.33     14         38.2
# 12  2017-01-13     Friday      19    0.3      1.33     15         37.5
# ...

# %%
df[-1:]
# Out:
#           Date     Day  Flyers  Price  Rainfall  Sales  Temperature  \
# 364 2017-12-31  Sunday       9    0.3       2.5      7         15.1
#
#                           _id
# 364  5b5b0008d827472478e6a42a

# %%
df.iloc[0:3, 1:4]
# Out:
#        Day  Flyers  Price
# 0   Sunday      15    0.3
# 1   Monday      15    0.3
# 2  Tuesday      27    0.3

# %%
df.iloc[0:4, 1:4]
# Out:
#          Day  Flyers  Price
# 0     Sunday      15    0.3
# 1     Monday      15    0.3
# 2    Tuesday      27    0.3
# 3  Wednesday      28    0.3

# %%
df[(df.Flyers >= 15) & (df.Flyers <= 20)]
# Out:
#           Date        Day  Flyers  Price  Rainfall  Sales  Temperature  \
# 0   2017-01-01     Sunday      15    0.3      2.00     10         27.0
# 1   2017-01-02     Monday      15    0.3      1.33     13         28.9
# 6   2017-01-07   Saturday      19    0.3      1.54     13         32.9
# 8   2017-01-09     Monday      20    0.3      1.18     17         38.1
# 11  2017-01-12   Thursday      16    0.3      1.33     14         38.2
# 12  2017-01-13     Friday      19    0.3      1.33     15         37.5
# 19  2017-01-20     Friday      20    0.3      1.43     12         31.6
# 20  2017-01-21   Saturday      16    0.3      1.25     14         36.2
# 21  2017-01-22     Sunday      19    0.3      1.11     16         40.8
# 23  2017-01-24    Tuesday      20    0.3      1.54     12         28.6
# 25  2017-01-26   Thursday      18    0.3      1.25     16         35.8
# 27  2017-01-28   Saturday      15    0.3      1.33     13         34.9
# ...

# %%
df[(df.Day != ("Sunday","Monday")) & (df.Flyers <= 20)]
# Out:
#           Date        Day  Flyers  Price  Rainfall  Sales  Temperature  \
# 0   2017-01-01     Sunday      15    0.3      2.00     10         27.0
# 1   2017-01-02     Monday      15    0.3      1.33     13         28.9
# 6   2017-01-07   Saturday      19    0.3      1.54     13         32.9
# 8   2017-01-09     Monday      20    0.3      1.18     17         38.1
# 11  2017-01-12   Thursday      16    0.3      1.33     14         38.2
# 12  2017-01-13     Friday      19    0.3      1.33     15         37.5
# 19  2017-01-20     Friday      20    0.3      1.43     12         31.6
# 20  2017-01-21   Saturday      16    0.3      1.25     14         36.2
# 21  2017-01-22     Sunday      19    0.3      1.11     16         40.8
# 23  2017-01-24    Tuesday      20    0.3      1.54     12         28.6
# 25  2017-01-26   Thursday      18    0.3      1.25     16         35.8
# 27  2017-01-28   Saturday      15    0.3      1.33     13         34.9
# ...

# %%
#df.to_csv("")

# %%
df[(df.Day == "Monday") & (df.Temperature <= 30)]
# Out:
#         Date     Day  Flyers  Price  Rainfall  Sales  Temperature  \
# 1 2017-01-02  Monday      15    0.3      1.33     13         28.9
#
#                         _id
# 1  5b5b0008d827472478e6a2bf

# %%
import matplotlib.pyplot as plt

X = [590,540,740,130,810,300,320,230,470,620,770,250]
Y = [32,36,39,52,61,72,77,75,68,57,48,48]

plt.scatter(X,Y)
plt.show()

# %%
import matplotlib.pyplot as plt

df2 = pd.DataFrame(np.random.rand(10, 2), columns=['Temperature', 'Flyers'])

# %%
df2.plot.bar();

# %%
df2.plot.hist(alpha=0.5);

# %%
df2.plot.hist(stacked=True, bins=20)

# %%
df2.plot.box()
